# %% [markdown]
# PANUTAD SIRIKUL
#
# 650510714
#
# Lab01
#
# 229351 Sec 001

# %% [markdown]
# Comprehensive list

# %%
# Comprehensive list
print([x**2 for x in range(11)])
[x**2 for x in range(1, 11, 2)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# [1, 9, 25, 49, 81]

# %% [markdown]
# ปฏิบัติการครั้งที่ 1 กระบวนวิชา 229351 Statistical Learning for Data Science
#
# คำชี้แจง
#
# 1. ให้เริ่มทำปฏิบัติการจาก colab notebook ที่กำหนดให้ **เมื่อเสร็จแล้วให้ทำการ share** จากนั้นส่ง link มาใน mango canvas
#
# ในขั้นตอนแรก ขอให้ download ไฟล์ที่
#
# http://donlapark.pages.dev/229351/data/housing.csv

# %%
import pandas as pd #dataframes
import numpy as np #matrices
import matplotlib.pyplot as plt #for plotting

# %matplotlib inline

# !wget http://donlapark.pages.dev/229351/data/housing.csv

housing = pd.read_csv("housing.csv")

housing.head(10)
# Out:
# --2023-11-16 04:20:28--  http://donlapark.pages.dev/229351/data/housing.csv
# Resolving donlapark.pages.dev (donlapark.pages.dev)... 172.66.44.200, 172.66.47.56, 2606:4700:310c::ac42:2f38, ...
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.44.200|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://donlapark.pages.dev/229351/data/housing.csv [following]
# --2023-11-16 04:20:28--  https://donlapark.pages.dev/229351/data/housing.csv
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.44.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/csv]
# Saving to: ‘housing.csv’
#
# housing.csv         100%[===================>]   1.36M  --.-KB/s    in 0.03s
#
# 2023-11-16 04:20:29 (43.7 MB/s) - ‘housing.csv’ saved [1423529/1423529]
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
housing.head(10)  # ดูข้อมูล 10 แถวแรก
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %% [markdown]
# ## Basic data exploration

# %%
housing.shape  # คำสั่งที่ไม่มีวงเล็บ คือ attribute
# Out:
# (20640, 10)

# %%
housing.info()  # คำสั่งนี้มีวงเล็บจึงเรียกว่า method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Which variable has missing data?

# %%
housing = housing.dropna()

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563700
# 50%        435.000000   1166.000000    409.000000       3.536500
# 75%        647.000000   1722.000000    604.000000       4.744000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20433.000000
# mean        206864.413155
# std         115435.667099
# min          14999.000000
# 25%         119500.000000
# 50%         179700.000000
# 75%         264700.000000
# max         500001.000000

# %% [markdown]
# ##Exercise 1
#
# 1. Download ไฟล์ข้อมูลที่
#   http://donlapark.pages.dev/229351/data/Advertising.csv
#   ซึ่งเป็นข้อมูลของผลการขายสินค้าอย่างหนึ่ง (Sales) กับการโฆษณาผ่านทาง TV, Radio, Newspaper
# 2. สร้าง dataframe ชื่อว่า **Ads** โดยใช้ข้อมูลชุดนี้
# 3. ดูข้อมูล 5 แถวแรกของ `Ads`
# 4. ตรวจสอบว่ามีข้อมูลที่หายไปหรือไม่
# 5. แสดงค่าสถิติพรรณนา (Descriptive statistics) ของตัวแปรต่างๆ

# %% [markdown]
# ## Calling, indexing & modifying dataframes

# %%
# calling a column

housing['ocean_proximity']
# Out:
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
#            ...
# 20635      INLAND
# 20636      INLAND
# 20637      INLAND
# 20638      INLAND
# 20639      INLAND
# Name: ocean_proximity, Length: 20433, dtype: object

# %% [markdown]
# `ocean_proximity` is categorical. Let's count its values.

# %%
housing["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ## Basic statistics of a variable

# %%
print("Mean: ",housing["total_rooms"].mean())
print("Standard deviation: ",housing["total_rooms"].std())
print("Maximum: ",housing["total_rooms"].max())
print("Minimum: ",housing["total_rooms"].min())
# Out:
# Mean:  2636.5042333480155
# Standard deviation:  2185.2695669775953
# Maximum:  39320.0
# Minimum:  2.0

# %%
housing[["longitude", "latitude", "housing_median_age"]]
# Out:
#        longitude  latitude  housing_median_age
# 0        -122.23     37.88                41.0
# 1        -122.22     37.86                21.0
# 2        -122.24     37.85                52.0
# 3        -122.25     37.85                52.0
# 4        -122.25     37.85                52.0
# ...          ...       ...                 ...
# 20635    -121.09     39.48                25.0
# 20636    -121.21     39.49                18.0
# 20637    -121.22     39.43                17.0
# 20638    -121.32     39.43                18.0
# 20639    -121.24     39.37                16.0
#
# [20433 rows x 3 columns]

# %%
housing.loc[0]  # ดึงข้อมูลแถวที่ 1
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age        41.0
# total_rooms              880.0
# total_bedrooms           129.0
# population               322.0
# households               126.0
# median_income           8.3252
# median_house_value    452600.0
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %% [markdown]
# ## Extracting a subset of dataframe

# %%
housing.loc[1:3, ["longitude","latitude"]]
# Out:
#    longitude  latitude
# 1    -122.22     37.86
# 2    -122.24     37.85
# 3    -122.25     37.85

# %%
housing.iloc[2:5,:]  # ถ้าดึงแบบ python (.iloc) จะไม่ดึงแถวสุดท้ายมา (แถวที่ 5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ## Selecting rows based on conditions

# %%
housing[housing['latitude']>=40]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1102     -121.54     40.06                17.0        858.0           262.0
# 1850     -124.17     41.80                16.0       2739.0           480.0
# 1851     -124.30     41.80                19.0       2672.0           552.0
# 1852     -124.23     41.75                11.0       3159.0           616.0
# 1853     -124.21     41.77                17.0       3461.0           722.0
# ...          ...       ...                 ...          ...             ...
# 19802    -123.17     40.31                36.0         98.0            28.0
# 19803    -123.22     40.16                27.0       1848.0           449.0
# 19804    -123.48     40.34                19.0        518.0           108.0
# 19805    -123.43     40.22                20.0        133.0            35.0
# 19806    -123.41     40.07                17.0        449.0           151.0
#
#        population  households  median_income  median_house_value  \
# 1102         47.0        27.0         2.4028             67500.0
# 1850       1259.0       436.0         3.7557            109400.0
# 1851       1298.0       478.0         1.9797             85800.0
# 1852       1343.0       479.0         2.4805             73200.0
# 1853       1947.0       647.0         2.5795             68400.0
# ...           ...         ...            ...                 ...
# 19802        18.0         8.0         0.5360             14999.0
# 19803       396.0       150.0         2.8472             41300.0
# 19804       216.0        80.0         2.7083             64500.0
# 19805        87.0        37.0         3.6250             67500.0
# 19806       141.0        53.0         0.8362             87500.0
#
#       ocean_proximity
# 1102           INLAND
# 1850       NEAR OCEAN
# 1851       NEAR OCEAN
# 1852       NEAR OCEAN
# 1853       NEAR OCEAN
# ...               ...
# 19802          INLAND
# 19803          INLAND
# 19804          INLAND
# 19805          INLAND
# 19806          INLAND
#
# [406 rows x 10 columns]

# %%
housing[(housing['longitude']>-122) & (housing['latitude']>=40)]  # & ต้องเป็น True ทั้งสองข้างจึงจะดึง
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1102     -121.54     40.06                17.0        858.0           262.0
# 3345     -121.11     41.07                26.0       1707.0           308.0
# 3346     -120.96     41.12                29.0        779.0           136.0
# 3347     -121.07     40.85                17.0        976.0           202.0
# 3348     -120.38     40.98                27.0        777.0           185.0
# ...          ...       ...                 ...          ...             ...
# 18823    -121.62     41.78                40.0       3272.0           663.0
# 18824    -121.93     41.86                28.0       4225.0           835.0
# 18858    -121.76     41.50                31.0        602.0           153.0
# 19735    -121.80     40.34                26.0       4815.0           910.0
# 19736    -121.78     40.12                14.0        388.0           108.0
#
#        population  households  median_income  median_house_value  \
# 1102         47.0        27.0         2.4028             67500.0
# 3345        761.0       250.0         2.7188             48100.0
# 3346        364.0       123.0         2.5000             59200.0
# 3347        511.0       175.0         3.6641             80800.0
# 3348        318.0       115.0         1.6833             40000.0
# ...           ...         ...            ...                 ...
# 18823      1467.0       553.0         1.7885             43500.0
# 18824      1908.0       686.0         1.7400             44000.0
# 18858       112.0        47.0         1.0667             34200.0
# 19735      1341.0       539.0         2.8810             79800.0
# 19736        35.0        17.0         6.1359            106300.0
#
#       ocean_proximity
# 1102           INLAND
# 3345           INLAND
# 3346           INLAND
# 3347           INLAND
# 3348           INLAND
# ...               ...
# 18823          INLAND
# 18824          INLAND
# 18858          INLAND
# 19735          INLAND
# 19736          INLAND
#
# [66 rows x 10 columns]

# %%
housing[(housing['longitude']>-122) | (housing['latitude']>=40)]  # หรือ | อย่างใดอย่่างหนึ่งเป็น True จึงจะดึง

# %% [markdown]
# ## Exercise 2
#
# ในข้อต่อไปนี้ ให้นับแถวและคอลัมน์เริ่มจาก 0
# 1. แสดงค่าสูงสุดของข้อมูลที่อยู่ในแถวที่ 200-400 ของตัวแปร `total_bedrooms`
# 2. แสดง 3 คอลัมน์สุดท้ายของพื้นที่ที่มีจำนวนห้องนอน (`total_bedrooms`) มากกว่า 900 ห้อง

# %%
# 1. แสดงค่าสูงสุดของข้อมูลที่อยู่ในแถวที่ 200-400 ของตัวแปร total_bedrooms
maximum_value = housing.loc[200:400, ["total_bedrooms"]]
maximum_value.max()
# Out:
# total_bedrooms    2048.0
# dtype: float64

# %%
# 2.  แสดง 3 คอลัมน์สุดท้ายของพื้นที่ที่มีจำนวนห้องนอน (total_bedrooms) มากกว่า 900 ห้อง
result = housing[housing['total_bedrooms']>900]
result[['median_income','median_house_value','ocean_proximity']]
# Out:
#        median_income  median_house_value ocean_proximity
# 1             8.3014            358500.0        NEAR BAY
# 95            2.0096            130000.0        NEAR BAY
# 96            2.8345            183800.0        NEAR BAY
# 98            1.2185            170000.0        NEAR BAY
# 99            2.6104            193100.0        NEAR BAY
# ...              ...                 ...             ...
# 20563         3.1250            132500.0          INLAND
# 20567         5.3064            165000.0          INLAND
# 20569         4.1997            133400.0          INLAND
# 20603         1.3375             59600.0          INLAND
# 20629         2.0943            108300.0          INLAND
#
# [2382 rows x 3 columns]

# %% [markdown]
# ##Plotting

# %%
housing.hist(bins=20, figsize=(15,15))
plt.show()

# %%
housing["longitude"].hist(bins=20, figsize=(5,5))
plt.show()

# %%
housing.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY

# %%
housing.plot.scatter(x="longitude", y="latitude");

# %%
housing.plot.scatter(x="longitude", y="latitude", alpha=0.1)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
corr_matrix = housing.corr()
# 1 มีความสัมพันธ์เยอะ
# -1 มีความสัมพันธ์ตรงกันข้าม
# 0 ไม่มีคว่ามสัมพันธ์กันเลย
corr_matrix
# Out:
# <ipython-input-38-3f7fa1c63e48>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = housing.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# latitude                 -0.066983   -0.108997   -0.071774      -0.079626
# housing_median_age       -0.320451   -0.295787   -0.302768      -0.118278
# total_rooms               0.930380    0.857281    0.918992       0.197882
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907186       0.005087
# households                0.979728    0.907186    1.000000       0.013434
# median_income            -0.007723    0.005087    0.013434       1.000000
# median_house_value        0.049686   -0.025300    0.064894       0.688355
#
#                     median_house_value
# longitude                    -0.045398
# latitude                     -0.144638
# housing_median_age            0.106432
# total_rooms                   0.133294
# total_bedrooms                0.049686
# population                   -0.025300
# households                    0.064894
# median_income                 0.688355
# median_house_value            1.000000

# %% [markdown]
# ### Grouping
#
# พิจารณา Anscombe dataset ข้างล่างนี้

# %%
import seaborn as sns

df = sns.load_dataset('anscombe')

# %%
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
groups = df.groupby('dataset')

# %%
groups  # ได้ object

# %%
groups.get_group('I')
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
groups.max()
# Out:
#             x      y
# dataset
# I        14.0  10.84
# II       14.0   9.26
# III      14.0  12.74
# IV       19.0  12.50

# %% [markdown]
# ## Exercise 3
#
# 1. คำนวณค่า mean, standard deviation และ correlation matrix ของแต่ละกลุ่ม
# 2. สร้าง scatter plot ของแต่ละกลุ่มด้วย `groups.plot.scatter(...)`
# 3. ลองเปรียบเทียบระหว่างคำตอบที่ได้ในข้อ 1 และข้อ 2 เรามีข้อสังเกตอะไรบ้าง

# %%
# 1. คำนวณค่า mean, standard deviation และ correlation matrix ของแต่ละกลุ่ม
groups.mean()
# Out:
#            x         y
# dataset
# I        9.0  7.500909
# II       9.0  7.500909
# III      9.0  7.500000
# IV       9.0  7.500909

# %%
groups.std()
# Out:
#                 x         y
# dataset
# I        3.316625  2.031568
# II       3.316625  2.031657
# III      3.316625  2.030424
# IV       3.316625  2.030579

# %%
groups.corr()
# Out:
#                   x         y
# dataset
# I       x  1.000000  0.816421
#         y  0.816421  1.000000
# II      x  1.000000  0.816237
#         y  0.816237  1.000000
# III     x  1.000000  0.816287
#         y  0.816287  1.000000
# IV      x  1.000000  0.816521
#         y  0.816521  1.000000

# %%
# 2. สร้าง scatter plot ของแต่ละกลุ่มด้วย groups.plot.scatter(...)
groups.plot.scatter(x="x", y="y")
# Out:
# dataset
# I      Axes(0.125,0.11;0.775x0.77)
# II     Axes(0.125,0.11;0.775x0.77)
# III    Axes(0.125,0.11;0.775x0.77)
# IV     Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
# 3. ลองเปรียบเทียบระหว่างคำตอบที่ได้ในข้อ 1 และข้อ 2 เรามีข้อสังเกตอะไรบ้าง

# %% [markdown]
# ข้อมูลทั้ง 4 กลุ่ม มีค่าทางสถิติที่ไม่แตกต่างกันมาก ทั้งค่าเฉลี่ย, ค่าส่วนเบี่ยงเบนมาตรฐาน, และค่าเมทริกซ์สหสัมพันธ์
#
#
# แต่เมื่อนำข้อมูลแต่ละกลุ่มมา Plot กราฟ Scatter Plot จะพบว่าข้อมูลแต่ละกลุ่มมีการกระจายที่แตกต่างกันมาก
